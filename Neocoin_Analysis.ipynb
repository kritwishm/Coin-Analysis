# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.plotly as py
import plotly.graph_objs as go
# %matplotlib inline

import plotly
plotly.tools.set_credentials_file(username='kritwishm', api_key='0m9QAcWuQ0LdA7BSmop5')

# %% [markdown]
# ### Reding the CSV file using Pandas Dataframe

# %%
data = pd.read_csv('neo.csv',parse_dates=['date'])
data = data.set_index('date')
data.tail()
# Out:
#             txVolume(USD)  txCount  marketcap(USD)  price(USD)  \
# date
# 2019-01-24     9611695.17   6113.0    4.932297e+08        7.59
# 2019-01-25    16031329.68   5989.0    5.044830e+08        7.76
# 2019-01-26    11055297.99   6050.0    4.936276e+08        7.59
# 2019-01-27    13410742.02   6985.0    4.900548e+08        7.54
# 2019-01-28     9961609.04   6496.0    4.832110e+08        7.43
#
#             exchangeVolume(USD)      fees  activeAddresses
# date
# 2019-01-24           95665449.0  4.765840           2940.0
# 2019-01-25          106034923.0  2.972808           2989.0
# 2019-01-26           93847643.0  3.526403           2980.0
# 2019-01-27          120602207.0  5.072027           3291.0
# 2019-01-28          138166064.0  5.162282           2969.0

# %% [markdown]
# ### Table Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 872 entries, 2016-09-09 to 2019-01-28
# Data columns (total 7 columns):
# txVolume(USD)          834 non-null float64
# txCount                834 non-null float64
# marketcap(USD)         872 non-null float64
# price(USD)             872 non-null float64
# exchangeVolume(USD)    872 non-null float64
# fees                   834 non-null float64
# activeAddresses        834 non-null float64
# dtypes: float64(7)
# memory usage: 54.5 KB

# %% [markdown]
# ### Number null values in each column

# %%
data.isnull().sum()
# Out:
# txVolume(USD)          38
# txCount                38
# marketcap(USD)          0
# price(USD)              0
# exchangeVolume(USD)     0
# fees                   38
# activeAddresses        38
# dtype: int64

# %% [markdown]
# ### Heat Map for null values

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')  #Null values in the dataset

# %% [markdown]
# # Price change over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['price(USD)'],
    name = "Price (USD)",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Price(USD) v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Price(USD)'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/159.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Price attained by this coin is $187.97 on 15th Jan 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Fees change over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['fees'],
    name = "Fees",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Fees v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Fees'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/161.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Fees attained by this coin is $495.18 on 2nd Sep 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Exchange Volume(USD) change over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['exchangeVolume(USD)'],
    name = "Exchange Volume(USD)",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Exchange Volume(USD) v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Exchange Volume(USD)'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/163.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Exchange Volume attained by this coin is $1.66B on 15th Jan 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Active Address change over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['activeAddresses'],
    name = "Active Addresses",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Active Addresses v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Active Addresses'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/165.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Number of Active Addresses attained by this coin is 47626 on 14th Jan 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Transaction Volume(USD) over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['txVolume(USD)'],
    name = "Transaction Volume(USD)",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Transaction Volume(USD) v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Transaction Volume(USD)'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/167.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Transaction Volume attained by this coin is $4.38B on 14th Jan 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Transaction Count change over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['txCount'],
    name = "Transaction Count",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Transaction Count v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Transaction Count'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/169.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Number of Transaction Count attained by this coin is 100.46k on 14th Jan 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Market Capital(USD) change over time

# %%
trace = go.Scatter(
    x=data.index,
    y=data['marketcap(USD)'],
    name = "Market Capital(USD)",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

data1 = [trace]

layout = dict(
    title='Market Capital(USD) v/s Time',
    xaxis=dict(
        title='Time',
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    ),
    yaxis=dict(
       title='Market Capital(USD)'
    )
)

fig = dict(data=data1, layout=layout)
py.iplot(fig)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kritwishm/171.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# The Maximum Market Capital attained by this coin is $12.2B on 15th Jan 2018. You can confirm it by moving the cursor on the graph.

# %% [markdown]
# # Correlational Heat Map

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# # Scatter Plot of Exchange Volume(USD) vs Price(USD)

# %%
sns.set_style('darkgrid')
sns.lmplot(x='price(USD)',y='exchangeVolume(USD)',data=data)
# Out:
# /home/kritwish/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %% [markdown]
# # Scatter Plot of Transaction Count vs Active Addresses

# %%
sns.lmplot(x='activeAddresses',y='txCount',data=data)

# %% [markdown]
# # Scatter Plot of Price(USD) vs Active Addresses

# %%
sns.lmplot(x='activeAddresses',y='price(USD)',data=data)

# %% [markdown]
# ### Column Names

# %%
data.columns
# Out:
# Index(['txVolume(USD)', 'txCount', 'marketcap(USD)', 'price(USD)',
#        'exchangeVolume(USD)', 'fees', 'activeAddresses'],
#       dtype='object')

# %% [markdown]
# ## Scatter Plot of Exchange Volume(USD) vs Price(USD) w.r.t. Transaction Count, Fees, Active Addresses respectively.

# %%
fig, (ax, ax2, ax3) = plt.subplots(ncols=3, sharey=True)
data.plot.scatter(x='price(USD)',y='exchangeVolume(USD)',c='txCount',cmap='viridis',figsize=(15,6),ax=ax)
data.plot.scatter(x='price(USD)',y='exchangeVolume(USD)',c='fees',cmap='coolwarm',figsize=(15,6),ax=ax2)
data.plot.scatter(x='price(USD)',y='exchangeVolume(USD)',c='activeAddresses',cmap='inferno',figsize=(15,6),ax=ax3)
plt.tight_layout()

# %% [markdown]
# # Density Plot for Transaction Count

# %%
plt.figure(figsize=(10,7))
sns.distplot(data['txCount'],hist=False,kde=True,kde_kws = {'shade': True, 'linewidth': 0.5})
plt.xlabel('Transaction Count')
# Out:
# Text(0.5, 0, 'Transaction Count')

# %% [markdown]
# Mostly the transaction count was between 3000-4000.

# %% [markdown]
# # Density Plot for Active Addresses

# %%
plt.figure(figsize=(10,7))
sns.distplot(data['activeAddresses'],hist=False,kde=True,kde_kws = {'shade': True, 'linewidth': 0.5})
plt.xlabel('Active Addresses')
# Out:
# Text(0.5, 0, 'Active Addresses')

# %% [markdown]
# Most of the days the Active Addresses were between 1000-2000.
